# %% [markdown]
# # Bessel Functions

# %%
import numpy as np 
import scipy as scip
import matplotlib.pyplot as plt
from scipy import special

# defining domain
x = np.linspace(0,20,1000)
# calculated bessel function
#J = np.empty(len(x))
#
J = special.jv(0,x)
plt.plot(x,J)
